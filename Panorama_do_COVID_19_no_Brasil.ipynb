# %% [markdown]
# <a href="https://colab.research.google.com/github/roberto-paixao/analise_covid_mundial/blob/main/Panorama_do_COVID_19_no_Brasil.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Panorama do COVID-19 no Brasil
# ---
#
# De acordo com o [Ministério da Saúde](https://coronavirus.saude.gov.br/sobre-a-doenca), os coronavírus são uma grande família de vírus comuns em muitas espécies diferentes de animais, incluindo camelos, gado, gatos e morcegos e raramente podem infectar humanos como foi o caso do MERS-CoV e SARS-CoV. A COVID-19 é uma doença infecciosa causada pelo recém-descoberto coronavírus SARS-CoV-2.
#
# Transmitido principalmente por meio de gotículas provenientes de tosses ou espirros de pessoas infectadas, a gravidade dos sintomas varia muito de pessoa para pessoa.
#
#
#
# Até o presente momento, observa-se que cerca de 80% dos casos confirmados são assintomáticos ou oligossintomáticos (poucos sintomas) e rápidos. A maioria das pessoas que se encaixam nesse grupo, se recuperam sem nenhuma sequela.
#
# No entanto, cerca de 20% dos casos confirmados apresentam dificuldade respiratória e necessitam de assistência hospitalar dos quais 5% podem precisar de suporte ventilatório.
#
# <img width="35%" src="https://image.freepik.com/vetores-gratis/tema-de-coronavirus-com-sinal-de-risco-biologico-em-fundo-branco_1308-42062.jpg">
#
# Com o objetivo de elevar a consciência situacional a respeito do COVID-19, irei realizar uma análise sobre os dados públicos da doença sob a perspectiva Mundial e Brasileira.

# %% [markdown]
# ## Obtenção dos Dados
#
# No ínicio da Pandemia, do final de 2019 para o primeiro semestre de 2020, pouco se sabia sobre a nova doença e o que se sabiam, muitas vezes eram informações conflitantes entre diversas fontes por se tratarem de pesquisas iniciais ou falta de organização dos dados, como por exemplo, a divergência entre os dados informados sobre a situação da Covid-19 pelos governos estaduais e federais e fontes não-oficiais o que faziam com que as análises não refletissem a realidade.
#
# Agora, em Junho de 2021, temos um conhecimento mais sólido sobre a nova doença e já temos vacinas desenvolvidas e sendo distribuídas ao redor do mundo.
#
# Os dados mundiais foram obtidos através do portal [Our World in Data](https://ourworldindata.org/coronavirus), onde é atualizado diariamente com a data de novos casos confirmados, mortes, casos hospitalizados, testagem e vacinações e também outras variáveis de potencial interesse.
#
# Para os dados brasileiros, usaremos os dados disponibilizados pelo Ministério da Saúde através do _dataset_ de [**wcota**](https://github.com/wcota/covid19br) em conjunto com o dataset do **OWID**.

# %% [markdown]
# ## Dicionário de Variáveis
#
# O dicionário de variáveis facilitará o entendimento a cerca dos atributos dos datasets.
#
# ### **Dicionário de Variáveis - OWID**<br>
#
# |Atributo|Descrição|
# |:-------|:---------|
# | iso_code | Código do país de 3 letras.|
# | continent | Continente da localização geográfica.|
# | location | Localização geográfica.|
# | date | Data da observação.|
# | total_cases | Total de casos confirmados de COVID-1|
# | new_cases | Novos casos confirmados de COVID-19.|
# | new_cases_smoothed | Novos casos confirmados (Suavizado por 7-dias).|
# | total_deaths | Total de mortes atribuídas por COVID-19.|
# | new_deaths | Novas mortes atribuídas por COVID-19 .|
# | new_deaths_smoothed | Novas mortes atribuídas por COVID-19 (Suavizado por 7-dias).
# | total_cases_per_million | Total de casos de COVID-19 por milhão de pessoas.
# | new_cases_per_million | Novos casos confirmados de COVID-19 por milhão de pessoas.
# | new_cases_smoothed_per_million | Novos casos confirmados de COVID-19 por milhão de pessoas (Suavizado por 7-dias).
# | total_deaths_per_million | Total de mortes por COVID-19 por milhão de pessoas.
# | new_deaths_per_million | Novas mortes por COVID-19 por milhão de pessoas.
# | new_deaths_smoothed_per_million | Novas mortes por COVID-19 por milhão de pessoas (Suavizado por 7-dias).
# | reproduction_rate | Estimativa em tempo real da taxa efetiva de reprodução (R) do COVID-19.
# | icu_patients | Número de pacientes COVID-19 em unidades de terapia intensiva (UTI) em um determinado dia.
# | icu_patients_per_million | Número de pacientes COVID-19 em unidades de terapia intensiva (UTI) em um determinado dia por 1.000.000 de pessoas.
# | hosp_patients | Número de pacientes hospitalizados no dado dia.
# | hosp_patients_per_million | Número de pacientes hospitalizados no dado dia por milhão de pessoas.
# | weekly_icu_admissions | Número de novos pacientes em UTI's no dado dia.
# | weekly_icu_admissions_per_million | Número de novos pacientes em UTI's no dado dia por milhão de pessoas.
# | weekly_hosp_admissions | Número de novos pacientes de COVID-19 hospitalizados na semana.
# | weekly_hosp_admissions_per_million | Número de novos pacientes de COVID-19 hospitalizados na semana por milhão de pessoas.
# | total_tests | Total de testes para COVID-19
# | new_tests | Novos testes para COVID-19 (calculado apenas para dias consecutivos).
# | total_tests_per_thousand | Total de testes para COVID-19 por mil pessoas.
# | new_tests_per_thousand | Novos testes para COVID-19 por mil pessoas.
# | new_tests_smoothed | Novos testes para COVID-19 (Suavizado por 7 dias)
# | new_tests_smoothed_per_thousand | Novos testes para COVID-19 (Suavizado por 7 dias) por mil pessoas.
# | positive_rate | A parcela de testes COVID-19 que são positivos, dada como uma média suavizada por 7 dias (Inverso de _`tests_per_case`_).
# | tests_per_case | Testes conduzidos para cada novo caso confirmado de COVID-19, suavizado por 7 dias (Inverso de _`positive_rate`_)
# | tests_units | Unidades usadas pela localidade para reportar os dados de testes.
# | total_vaccinations | Total de vacinas administradas.
# | people_vaccinated | Total de pessoas que receberam pelo menos uma dose da vacina.
# | people_fully_vaccinated | Total de pessoas que receberam todas as doses prescritas pelos protocolos de vacinação.
# | new_vaccinations | Novas doses de vacinas administradas (Contado apenas por dias consecutivos).
# | new_vaccinations_smoothed | Novas doses de vacinas administradas (Suavizado por 7 dias)
# | total_vaccinations_per_hundred | Quantidade de doses administradas por 100 pessoas no total de população.
# | people_vaccinated_per_hundred | Total de pessoas que receberam pelo menos uma dose da vacina por 100 pessoas na população total
# | people_fully_vaccinated_per_hundred | Total de pessoas que receberam todas as doses preescritas pelo protocolo de vacinação por 100 pessoas na população total.|
# | new_vaccinations_smoothed_per_million | Novas doses de vacinação COVID-19 administradas (suavizadas em 7 dias) por 1.000.000 de pessoas na população total.|
# | stringency_index | Índice de Restrição de Resposta do Governo: medida composta com base em 9 indicadores de resposta, <br>incluindo fechamentos de escolas, fechamentos de locais de trabalho e proibições de viagens, <br>redimensionado para um valor de 0 a 100 (100 = resposta mais estrita).|
# | population | População em 2020.|
# | population_density | Número de pessoas dividido por área terrestre, medido em quilômetros quadrados, ano mais recente disponível.|
# | median_age | Idade média da população, projeção da ONU para 2020.|
# | aged_65_older | Parcela da população com 65 anos ou mais, ano mais recente disponível.|
# | aged_70_older | Parcela da população com 70 anos ou mais em 2015.|
# | gdp_per_capita | Produto interno bruto em paridade de poder de compra (dólares internacionais constantes de 2011), ano mais recente disponível.|
# | extreme_poverty | Parcela da população que vive em pobreza extrema, ano mais recente disponível desde 2010.|
# | cardiovasc_death_rate | Taxa de mortalidade por doenças cardiovasculares em 2017 (número anual de mortes por 100.000 pessoas).|
# | diabetes_prevalence | Prevalência de diabetes (% da população de 20 a 79 anos) em 2017|
# | female_smokers | Parcela de mulheres que fumam, ano mais recente disponível.|
# | male_smokers | Parcela de homens que fumam, ano mais recente disponível|
# | handwashing_facilities | Parcela da população com instalações básicas para lavagem das mãos no local, ano mais recente disponível.|
# | hospital_beds_per_thousand | Leitos hospitalares por 1.000 pessoas, ano mais recente disponível desde 2010.|
# | life_expectancy | Expectativa de vida ao nascer em 2019.|
# | human_development_index | Um índice composto que mede o desempenho médio em três dimensões básicas do desenvolvimento humano uma vida longa e saudável,<br>conhecimento e um padrão de vida decente. Valores para 2019.|
#
#
# ### **Dicionário de Variáveis - wcota**<br>
#
# |Atributo|Descrição|
# |:-------|:---------|
# |epi_week | Número da semana epidemiológica |
# | date | Data de divulgação|
# | country | Nome do país (sempre Brazil)|
# | state | Nome da unidade federativa|
# | city | Sempre “TOTAL”|
# | newDeaths | Número de novos óbitos divulgados|
# | deaths | Número acumulado de óbitos|
# | newCases | Número de novos casos divulgados|
# | totalCases | Número acumulado de casos|
# | deathsMS | Número acumulado de obitos pelo Ministério da Saúde|
# | totalCasesMS | Número acumulado de casos pelo Ministério da Saúde|
# | deaths_per_100k_inhabitants | Número de óbitos por 100 mil habitantes|
# | totalCases_per_100k_inhabitants | Número de casos por 100 mil habitantes|
# | deaths_by_totalCases | Razão entre número de óbitos e casos (deaths/totalCases)|
# | recovered | Número de recuperados|
# | suspects | Número de suspeitos|
# | tests | Número de testes realizados|
# | tests_per_100k_inhabitants | Número de testes realizados por 100 mil habitantes|
# | vaccinated | Número de pessoas vacinadas (primeira dose)|
# | vaccinated_per_100k_inhabitants| Número de pessoas vacinadas (primeira dose) por 100 mil habitantes|
# | vaccinated_second | Número de pessoas que receberam a segunda dose|
# | vaccinated_second_per_100k_inhabitants | Número de pessoas que receberam a segunda dose por 100 mil habitantes.|
#
# ---

# %% [markdown]
# ## Importando os dados do COVID-19
#
#
# Usaremos o `csv` do dataset mundial que pode ser baixado através desse [link](https://raw.githubusercontent.com/roberto-paixao/analise_covid_mundial/main/data/owid-covid-data.csv) e o dataset com os dados brasileiros que pode ser encontrado por esse [link](https://raw.githubusercontent.com/roberto-paixao/analise_covid_mundial/main/data/wcota_brazil_dataset.csv).
#
# Logo a seguir, criaremos nosso DataFrame com a biblioteca `pandas` e importaremos as bibliotecas necessárias para a exploração e visualização de dados.
#
#
# # *** ATENÇÃO**
#
# <img src="https://www.pe.com/wp-content/uploads/2018/01/rpe-bus-bestlaw-warning.jpg?w=894" width=10%>
#
# > ***Esta análise tem finalidade puramente didática e não deve ser interpretada como uma verdade absoluta apesar da confiabilidade da fonte dos dados.***
#
# *Os dados desta análise foram atualizados até o dia **14 de Junho de 2021**. Os datasets atualizados e utilizados nessa análise podem ser encontrados no meu [github](https://github.com/roberto-paixao/analise_covid_mundial/tree/main/data).*

# %%
# Importando o pandas para gerar o DataFrame
import pandas as pd

# Importando as bibliotecas para criação de gráficos
import matplotlib.pyplot as plt
import seaborn as sns


# Configurações dos gráficos
# %matplotlib inline
sns.set_style()

# Gerando os DataFrames
DATA_PATH = "https://raw.githubusercontent.com/roberto-paixao/analise_covid_mundial/main/data/owid-covid-data.csv"
df = pd.read_csv(DATA_PATH)

DATA_PATH = "https://raw.githubusercontent.com/roberto-paixao/analise_covid_mundial/main/data/wcota_brazil_dataset.csv"
df_brasil = pd.read_csv(DATA_PATH)

# %% [markdown]
# Primeiramente, veremos a estrutura do dataset **OWID** e em como ele está organizado para entender o dataset que estamos lidando, posteriormente, veremos a estrutura do dataset **wcota** em uma seção própria.
#
#
# Veremos quantos atributos (_features_) e quantas observações (linhas) temos no _dataset_ e suas 5 primeiras e últimas linhas.

# %%
# Mostra as dimensões do dataset
print("Dimensões do Dataset",
      "\nAtributos (Features): ",df.shape[1],
      "\nObservações (Linhas): ",df.shape[0])

# Exibe as 5 primeiras linhas do dataset
df.head()
# Out:
# Dimensões do Dataset
# Atributos (Features):  60
# Observações (Linhas):  96001
#   iso_code continent  ... human_development_index excess_mortality
# 0      AFG      Asia  ...                   0.511              NaN
# 1      AFG      Asia  ...                   0.511              NaN
# 2      AFG      Asia  ...                   0.511              NaN
# 3      AFG      Asia  ...                   0.511              NaN
# 4      AFG      Asia  ...                   0.511              NaN
#
# [5 rows x 60 columns]

# %%
df.tail()
# Out:
#       iso_code continent  ... human_development_index excess_mortality
# 95996      ZWE    Africa  ...                   0.571              NaN
# 95997      ZWE    Africa  ...                   0.571              NaN
# 95998      ZWE    Africa  ...                   0.571              NaN
# 95999      ZWE    Africa  ...                   0.571              NaN
# 96000      ZWE    Africa  ...                   0.571              NaN
#
# [5 rows x 60 columns]

# %% [markdown]
# Vamos ver quais são os atributos (_features_) presentes no dataset

# %%
# Nome das colunas do dataset
df.columns.to_list()
# Out:
# ['iso_code',
#  'continent',
#  'location',
#  'date',
#  'total_cases',
#  'new_cases',
#  'new_cases_smoothed',
#  'total_deaths',
#  'new_deaths',
#  'new_deaths_smoothed',
#  'total_cases_per_million',
#  'new_cases_per_million',
#  'new_cases_smoothed_per_million',
#  'total_deaths_per_million',
#  'new_deaths_per_million',
#  'new_deaths_smoothed_per_million',
#  'reproduction_rate',
#  'icu_patients',
#  'icu_patients_per_million',
#  'hosp_patients',
#  'hosp_patients_per_million',
#  'weekly_icu_admissions',
#  'weekly_icu_admissions_per_million',
#  'weekly_hosp_admissions',
#  'weekly_hosp_admissions_per_million',
#  'new_tests',
#  'total_tests',
#  'total_tests_per_thousand',
#  'new_tests_per_thousand',
#  'new_tests_smoothed',
#  'new_tests_smoothed_per_thousand',
#  'positive_rate',
#  'tests_per_case',
#  'tests_units',
#  'total_vaccinations',
#  'people_vaccinated',
#  'people_fully_vaccinated',
#  'new_vaccinations',
#  'new_vaccinations_smoothed',
#  'total_vaccinations_per_hundred',
#  'people_vaccinated_per_hundred',
#  'people_fully_vaccinated_per_hundred',
#  'new_vaccinations_smoothed_per_million',
#  'stringency_index',
#  'population',
#  'population_density',
#  'median_age',
#  'aged_65_older',
#  'aged_70_older',
#  'gdp_per_capita',
#  'extreme_poverty',
#  'cardiovasc_death_rate',
#  'diabetes_prevalence',
#  'female_smokers',
#  'male_smokers',
#  'handwashing_facilities',
#  'hospital_beds_per_thousand',
#  'life_expectancy',
#  'human_development_index',
#  'excess_mortality']

# %% [markdown]
# Verificar os tipos de cada atributo nos permite ter uma visão geral sobre como tratar tais variáveis futuramente.

# %%
# Verificando o tipo de cada variável do dataset

df.dtypes
# Out:
# iso_code                                  object
# continent                                 object
# location                                  object
# date                                      object
# total_cases                              float64
# new_cases                                float64
# new_cases_smoothed                       float64
# total_deaths                             float64
# new_deaths                               float64
# new_deaths_smoothed                      float64
# total_cases_per_million                  float64
# new_cases_per_million                    float64
# new_cases_smoothed_per_million           float64
# total_deaths_per_million                 float64
# new_deaths_per_million                   float64
# new_deaths_smoothed_per_million          float64
# reproduction_rate                        float64
# icu_patients                             float64
# icu_patients_per_million                 float64
# hosp_patients                            float64
# hosp_patients_per_million                float64
# weekly_icu_admissions                    float64
# weekly_icu_admissions_per_million        float64
# weekly_hosp_admissions                   float64
# weekly_hosp_admissions_per_million       float64
# new_tests                                float64
# total_tests                              float64
# total_tests_per_thousand                 float64
# new_tests_per_thousand                   float64
# new_tests_smoothed                       float64
# new_tests_smoothed_per_thousand          float64
# positive_rate                            float64
# tests_per_case                           float64
# tests_units                               object
# total_vaccinations                       float64
# people_vaccinated                        float64
# people_fully_vaccinated                  float64
# new_vaccinations                         float64
# new_vaccinations_smoothed                float64
# total_vaccinations_per_hundred           float64
# people_vaccinated_per_hundred            float64
# people_fully_vaccinated_per_hundred      float64
# new_vaccinations_smoothed_per_million    float64
# stringency_index                         float64
# population                               float64
# population_density                       float64
# median_age                               float64
# aged_65_older                            float64
# aged_70_older                            float64
# gdp_per_capita                           float64
# extreme_poverty                          float64
# cardiovasc_death_rate                    float64
# diabetes_prevalence                      float64
# female_smokers                           float64
# male_smokers                             float64
# handwashing_facilities                   float64
# hospital_beds_per_thousand               float64
# life_expectancy                          float64
# human_development_index                  float64
# excess_mortality                         float64
# dtype: object

# %% [markdown]
# É importante verificar os valores ausentes e sua porcentagem em cada coluna do dataset, pois nos permite ter uma noção sobre como tratar esses dados ausentes bem como nos questionar sobre o porquê desses dados ausentes, o que nos levaria a uma análise mais detalhada e completa, entretanto, este não é o nosso foco agora.

# %%
# Verificando a porcentagem de valores ausentes do dataset.

round(df.isnull().mean().sort_values(ascending=False) * 100,2)
# Out:
# weekly_icu_admissions                    99.09
# weekly_icu_admissions_per_million        99.09
# weekly_hosp_admissions                   98.43
# weekly_hosp_admissions_per_million       98.43
# excess_mortality                         96.45
# icu_patients                             89.95
# icu_patients_per_million                 89.95
# people_fully_vaccinated_per_hundred      88.43
# people_fully_vaccinated                  88.43
# hosp_patients                            87.51
# hosp_patients_per_million                87.51
# new_vaccinations                         87.20
# people_vaccinated                        85.50
# people_vaccinated_per_hundred            85.50
# total_vaccinations_per_hundred           84.66
# total_vaccinations                       84.66
# new_vaccinations_smoothed_per_million    73.58
# new_vaccinations_smoothed                73.58
# total_tests                              55.20
# total_tests_per_thousand                 55.20
# new_tests_per_thousand                   54.89
# new_tests                                54.89
# handwashing_facilities                   54.82
# tests_per_case                           51.20
# positive_rate                            50.57
# new_tests_smoothed_per_thousand          47.62
# new_tests_smoothed                       47.62
# tests_units                              45.92
# extreme_poverty                          39.29
# male_smokers                             30.66
# female_smokers                           29.63
# reproduction_rate                        19.36
# hospital_beds_per_thousand               18.04
# stringency_index                         15.44
# total_deaths_per_million                 14.31
# new_deaths_per_million                   14.15
# total_deaths                             13.81
# new_deaths                               13.64
# aged_65_older                            11.48
# aged_70_older                            10.96
# median_age                               10.47
# gdp_per_capita                           10.16
# cardiovasc_death_rate                    10.07
# human_development_index                   9.90
# diabetes_prevalence                       7.85
# population_density                        7.05
# life_expectancy                           5.04
# new_deaths_smoothed_per_million           4.94
# new_cases_smoothed_per_million            4.94
# continent                                 4.71
# new_deaths_smoothed                       4.43
# new_cases_smoothed                        4.43
# new_cases_per_million                     3.89
# total_cases_per_million                   3.89
# new_cases                                 3.37
# total_cases                               3.37
# population                                0.66
# location                                  0.00
# date                                      0.00
# iso_code                                  0.00
# dtype: float64

# %% [markdown]
# No [GitHub](https://github.com/owid/covid-19-data/tree/master/public/data) do dataset **OWID**, há a informação de que os dados sobre as hospitalizações e internações são de apenas alguns países da Europa, dos Estados Unidos e do Canadá, motivo pelo qual quase todos os dados sobre essas categorias estão ausentes.
#
#
# Como observamos o nome das colunas, temos um atributo `date` relacionado a data, entretanto, a mesma se encontra em formato `object` o que não seria o ideal para explorarmos este atributo.
#
# Precisamos converter essa coluna para o tipo `datetime`.
# Faremos isso da seguinte forma:

# %%
# Convertendo para datetime e atribuindo os valores para a mesma coluna.
df.date = pd.to_datetime(df.date)

# %% [markdown]
# Para checar se a conversão foi um sucesso, usaremos um comando para verificar a data mais recente do dataset.

# %%
df.date.max()
# Out:
# Timestamp('2021-06-16 00:00:00')

# %% [markdown]
# > *Como dito anteriormente, o dataset está atualizado até a data de 14 de Junho de 2021, na data máxima em que o dataset se situa, algumas informações sobre alguns países entre os dias 15 e 16 ainda não foram atualizados, sendo assim, usaremos até o dia em que os dados sejam mais completos.*

# %% [markdown]
# Concluído o tratamento inicial de dados, podemos agora iniciar a **análise exploratória**
#
# ---

# %% [markdown]
# ## Análise Exploratória dos Dados
#
# <img src="https://image.freepik.com/fotos-gratis/close-up-do-homem-de-negocios-com-tabuleta-digital_1098-549.jpg" width=35%>
#
# Faremos uma análise geral dos dados a fim de extrair insights que nos situem a cerca da pandemia pelo mundo.
#
# Logo após, iremos analisar os dados sobre o Brasil para descobrir a situação em que o país está.

# %% [markdown]
# ### **Análise Exploratória Inicial**
#
# Temos diversas métricas disponíveis no dataset para usarmos, entretanto, algumas são mais úteis que outras e outras devem ser vistas com cautela pois podem confudir o entendimento a cerca da informação que ela deseja passar. Vamos observar a situação mundial em relação ao número (valores absolutos e média móvel) de casos , número de óbitos, a taxa de reprodução do vírus (R0) e taxas de testes positivos.
#
# Escolher as melhores métricas nos ajuda a compreender melhor a situação que queremos analisar e tirar _insights_.
#
# Na próxima seção usaremos as métricas mais recomendadas para analisar uma situação da pandemia.
#
# <img src="https://image.freepik.com/vetores-gratis/fundo-monocromatico-de-coronavirus_23-2148657491.jpg" width=35%>

# %% [markdown]
# #### **Evolução dos casos mundiais**
#
#
#
# Vamos começar olhando os números de casos e óbitos decorrentes da Covid-19, mas usar os números absolutos de casos e óbitos não é uma boa maneira de analisar esses dados mas se usarmos a média móvel de 7 dias podemos ver as tendências de crescimento ou declínio de casos ou óbitos no decorrer do tempo.
#
# A média móvel é calculada somando-se o número de casos/óbitos de cada um dos sete dias anteriores e dividindo esse resultado por 7. A taxa média de 7 dias suaviza as flutuações durante a semana e é um melhor indicador de tendência do que os números diários.

# %%
# Gráfico de méia móvel de novos casos

sns.set_style('ticks')
fig, ax = plt.subplots(figsize=(12,8))

novos_casos_suavizados = (df.loc[df.location == 'World', ['date', 'new_cases_smoothed']]
                          .reset_index(drop=True))

sns.lineplot(x='date', y='new_cases_smoothed',
             data=novos_casos_suavizados, ci=None, linewidth=3, color='DarkOrange')

ax.set_title('Média móvel (7 dias) de novos casos de COVID-19\n\n', color='Grey', size=20, loc='left')

ax.set_xlabel([], color='white')
ax.set_ylabel([], color='white')

ax.yaxis.set_ticklabels(['0', '0', '200K', '400K', '600K', '800K'])

sns.despine()
plt.tight_layout()

# %%
# Gráfico de méia móvel de novos óbitos

sns.set_style('ticks')
fig, ax = plt.subplots(figsize=(12,8))

novos_obitos_suavizados = (df.loc[df.location == 'World', ['date', 'new_deaths_smoothed']].reset_index(drop=True))

sns.lineplot(x='date', y='new_deaths_smoothed',
             data=novos_obitos_suavizados, ci=None, linewidth=3, color='DarkOrange')

ax.set_title('Média móvel (7 dias) de novos óbitos por COVID-19\n\n', color='Grey', size=20, loc='left')

ax.set_xlabel([], color='white')
ax.set_ylabel([], color='white')

ax.yaxis.set_ticklabels(['0', '0', '2K', '4K', '6K', '8K', '10K', '12K', '14K'])

sns.despine()
plt.tight_layout()

# %% [markdown]
# Olhando para a média móvel de novos casos e novos óbitos podemos ver as tendências durante o tempo e nos permite analisar melhor a situação da pandemia, passamos pela primeira e agora estamos saindo da segunda onda de infecções por Covid-19.
#
# Porém, tentar gerar uma previsão de uma possível terceira onda sobre essas tendências pode não ser uma boa escolha visto que previsões tendem a mudar muito por conta do comportamento das pessoas, por exemplo:
#
# * **Se os números de casos novos voltarem a aumentar, as pessoas vão começar a usar as máscaras e aplicar o distanciamento social novamente até que elas percebam que os casos estão diminuindo para então começar a relaxar nas medidas preventivas novamente.**

# %% [markdown]
# #### **Quais os países possuem mais casos?**
#
# Primeiro, veremos o número de casos absolutos pelo mundo na data estipulada:

# %%
(df.loc[(df.date == '2021-06-14') & df.continent.notnull(), ['iso_code', 'location', 'total_cases']].sort_values
 (by='total_cases',ascending = False)[:5])
# Out:
#       iso_code       location  total_cases
# 91491      USA  United States   33474734.0
# 40200      IND          India   29570881.0
# 12694      BRA         Brazil   17452612.0
# 31616      FRA         France    5803012.0
# 88862      TUR         Turkey    5336073.0

# %%
# Top 5 Casos

sns.set_style('white')
fig, ax = plt.subplots(figsize=(12,8))
total_cases_5 = (df.loc[(df.date == '2021-06-14') & df.continent.notnull()]
                 .sort_values(by='total_cases', ascending = False)[:5].copy())


splot = sns.barplot(x='location', y='total_cases', data=total_cases_5, ax=ax, color='DarkOrange')

for p in splot.patches:
    splot.annotate(int(p.get_height()),
                   (p.get_x() + p.get_width()/2, p.get_height()),
                   ha='center',
                   va='center',
                   size=15, 
                   color='white', 
                   fontweight='bold',
                   xytext=(0,-15),
                   textcoords='offset points')

ax.set_title('Os 5 países com mais casos de COVID-19\n', loc='left', size=20, color='grey')
ax.set_xlabel([], color='white')
ax.set_ylabel([], color='white')
ax.set_yticklabels([])
sns.despine(left=True, bottom=True)

plt.tight_layout()

# %% [markdown]
# Na data de 14 de Junho de 2021, os países que lideravam em total de casos são:
#
# * **Estados Unidos** - 33.474.734 casos
# * **India** - 29.570.881 casos
# * **Brasil** - 17.452.612 casos
# * **França** - 5.803.012 casos
# * **Turquia** - 5.336.073 casos
#
# Para poder comparar países com populações diferentes, devemos usar o total de casos normalizados por milhão de habitantes, para remover o efeito da população.

# %%
(total_cases_5.sort_values(by='total_cases_per_million', ascending=False)
[['location', 'total_cases_per_million']])
# Out:
#             location  total_cases_per_million
# 91491  United States               101131.318
# 31616         France                85888.793
# 12694         Brazil                82106.984
# 88862         Turkey                63269.291
# 40200          India                21428.107

# %%
# Top 5 casos por milhão de pessoas

sns.set_style('white')
fig, ax = plt.subplots(figsize=(12,8))

total_cases_5 = (df.loc[(df['date'] == '2021-06-14') & df.continent.notnull()]
                 .sort_values(by='total_cases', ascending = False)[:5].copy())

total_cases_5 = total_cases_5.sort_values(by='total_cases_per_million', ascending=False).copy()


splot = sns.barplot(x='location', y='total_cases_per_million',
                    data=total_cases_5, ax=ax, color='DarkOrange')

for p in splot.patches:
    splot.annotate(int(p.get_height()),
                   (p.get_x() + p.get_width()/2, p.get_height()),
                   ha='center',
                   va='center',
                   size=15, 
                   color='white', 
                   fontweight='bold',
                   xytext=(0,-15),
                   textcoords='offset points')

ax.set_title('Os 5 países com mais casos de COVID-19\n', loc='left', size=20, color='grey')
plt.suptitle('normalizados por milhão de habitantes.\n', x=0.175, y=0.940, size=12, color='grey')
ax.set_xlabel([], color='white')
ax.set_ylabel([], color='white')
ax.set_yticklabels([])
sns.despine(left=True, bottom=True)

plt.tight_layout()

# %% [markdown]
# Após a normalização dos números de casos por milhão de habitantes, com o intuíto de remover o efeito da população, os Estados Unidos permaneceram em 1º no ranking tanto em casos absolutos quanto em casos normalizados por milhão de habitantes **entre os países que possuem mais casos no mundo em termos absolutos**.
#
# Veremos agora quais países **realmente** possuem mais casos por milhão de habitantes.

# %%
# Top 5 casos por milhão de habitantes

sns.set_style('white')
fig, ax = plt.subplots(figsize=(12,8))

total_cases_5 = (df.loc[(df.date == '2021-06-14') & df.continent.notnull()]
                 .sort_values(by='total_cases_per_million', ascending = False)[:5].copy())


splot = sns.barplot(x='location', y='total_cases_per_million',
                    data=total_cases_5, ax=ax, color='DarkOrange')

for p in splot.patches:
    splot.annotate(int(p.get_height()),
                   (p.get_x() + p.get_width()/2, p.get_height()),
                   ha='center',
                   va='center',
                   size=15, 
                   color='white', 
                   fontweight='bold',
                   xytext=(0,-15),
                   textcoords='offset points')

ax.set_title('Os 5 países com mais casos por milhão de habitantes\nde COVID-19\n',
             loc='left', size=20, color='grey')

ax.set_xlabel([], color='white')
ax.set_ylabel([], color='white')
ax.set_yticklabels([])
sns.despine(left=True, bottom=True)

plt.tight_layout()

# %% [markdown]
# Andorra, Montenegro, Czechia, Bahrain e San Marino são os países que possuem mais casos por milhão de habitantes.

# %% [markdown]
# #### **Quais países possuem mais mortes?**
#
# O maior objetivo de uma resposta epidêmica é salvar vidas, portanto monitorar as mortes por COVID-19 é importante, principalmente quando o número de testes é limitado.

# %%
# Verificando o total de mortes

(df.loc[(df.date == '2021-06-14') & df.continent.notnull(), ['location', 'total_deaths']]
 .sort_values(by='total_deaths', ascending = False))[:5]
# Out:
#             location  total_deaths
# 91491  United States      599946.0
# 12694         Brazil      488228.0
# 40200          India      377031.0
# 56384         Mexico      230187.0
# 68835           Peru      188708.0

# %%
# Total de casos fatais

sns.set_style('white')
fig, ax = plt.subplots(figsize=(12,8))

total_death_5 = df.loc[(df.date == '2021-06-14') & df.continent.notnull()].sort_values(by='total_deaths', ascending = False)[:5].copy()


splot = sns.barplot(x='location', y='total_deaths',data=total_death_5, ax=ax, color='DarkOrange')

for p in splot.patches:
    splot.annotate(format(int(p.get_height())),
                   (p.get_x() + p.get_width()/2, p.get_height()),
                   ha='center',
                   va='center',
                   size=15, 
                   color='white', 
                   fontweight='bold',
                   xytext=(0,-15),
                   textcoords='offset points')

ax.set_title('5 países com mais registros de óbitos por COVID-19\n', loc='left', size=20, color='grey')
ax.set_xlabel([], color='white')
ax.set_ylabel([], color='white')
ax.set_yticklabels([])
sns.despine(left=True, bottom=True)

plt.tight_layout()

# %% [markdown]
# Os países com mais mortes em 14 de Junho de 2021 são: **Estados Unidos**, **Brasil**, **Índia**, **México** e **Peru** .
#
# Usaremos os dados normalizados para tirar o efeito do tamanho da população e podermos comparar os países.

# %%
# Casos fatais por milhão de habitantes

sns.set_style('white')
fig, ax = plt.subplots(figsize=(12,8))

total_deaths_per_m = (df.loc[(df.date == '2021-06-14') & df.continent.notnull()]
                      .sort_values(by='total_deaths', ascending = False)[:5].copy())

total_deaths_per_m = total_deaths_per_m.sort_values(by='total_deaths_per_million', ascending=False).copy()

                                                                                   
splot = sns.barplot(x='location', y='total_deaths_per_million',
                    data=total_deaths_per_m, ax=ax, color='DarkOrange')

for p in splot.patches:
    splot.annotate(format(int(p.get_height())),
                   (p.get_x() + p.get_width()/2, p.get_height()),
                   ha='center',
                   va='center',
                   size=15, 
                   color='white', 
                   fontweight='bold',
                   xytext=(0,-15),
                   textcoords='offset points')

ax.set_title('5 países com mais óbitos por Covid-19\n\n', loc='left', size=20, color='grey')
plt.suptitle('normalizados por milhão de habitantes.\n', x=0.175, y=0.940, size=12, color='grey')
ax.set_xlabel([], color='white')
ax.set_ylabel([], color='white')
ax.set_yticklabels([])
sns.despine(left=True, bottom=True)

plt.tight_layout()
# Out:
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 6.44 µs

# %% [markdown]
# Após normalizar o número de óbitos dos países que tiveram os maiores números, com o intuito de remover o efeito da população, **Peru** aparece com uma taxa bastante alta de óbitos por milhão de habitantes **entre os países que mais tiveram óbitos registrados no mundo.**
#
# Veremos quais os países que possuem mais óbitos por milhão de habitantes.

# %%
# Mortes por milão de habitantes

sns.set_style('white')
fig, ax = plt.subplots(figsize=(12,8))

total_cases_5 = df.loc[(df.date == '2021-06-14') & df.continent.notnull()].sort_values(by='total_deaths_per_million', ascending = False)[:5].copy()


splot = sns.barplot(x='location', y='total_deaths_per_million', data=total_cases_5, ax=ax, color='DarkOrange')

for p in splot.patches:
    splot.annotate(int(p.get_height()),
                   (p.get_x() + p.get_width()/2, p.get_height()),
                   ha='center',
                   va='center',
                   size=15, 
                   color='white', 
                   fontweight='bold',
                   xytext=(0,-15),
                   textcoords='offset points')

ax.set_title('Os 5 países com mais óbitos por milhão de habitantes\nde COVID-19\n', loc='left', size=22, color='grey')
ax.set_xlabel([], color='white')
ax.set_ylabel([], color='white')
ax.set_yticklabels([])
sns.despine(left=True, bottom=True)

plt.tight_layout()

# %% [markdown]
# Apesar de aparecer em 5º no ranking de óbitos absolutos, Peru ainda aparece com a maior taxa de óbitos por milhão de habitantes do mundo e logo em seguida se encontram Hungria, Bósnia e Herzegovina, República Tcheca e San Marino.

# %% [markdown]
# #### **Taxa de Reprodução** (R0)
#
# A **taxa de reprodução** (R0) do vírus nos informa se o vírus ainda está se espalhando ou se a epidemia está controlada.
#
# O **R0** é a média de pessoas que pegarão a doença de uma **única** pessoa infectada em uma população que nunca viu a doença antes. Isso quer dizer que, se o R0 for 3, significa que uma pessoa infectada criará, em média, 3 novos casos. Quando o R0 for **menor** que 1, significa que a epidemia está controlada e quando for **maior** que 1 significa que a doença ainda está espalhando.
#
# Vamos agora analisar a taxa de reprodução do vírus nos países.

# %%
maiores_r0 = (df.loc[(df.date == '2021-06-14') & (df.continent.notnull()), 
                     ['location', 'reproduction_rate']].sort_values(by='reproduction_rate',
                                                                    ascending=False))[:20]

maiores_r0.reset_index(drop=True)
# Out:
#                         location  reproduction_rate
# 0                      Mauritius               2.15
# 1                        Liberia               2.14
# 2                         Rwanda               2.06
# 3                   Sierra Leone               1.89
# 4                         Zambia               1.85
# 5                         Malawi               1.75
# 6                        Myanmar               1.73
# 7                       Zimbabwe               1.69
# 8                         Uganda               1.58
# 9                           Fiji               1.56
# 10                        Monaco               1.54
# 11                         Haiti               1.47
# 12                       Namibia               1.47
# 13  Democratic Republic of Congo               1.44
# 14                      Botswana               1.38
# 15                United Kingdom               1.37
# 16                          Oman               1.36
# 17                  South Africa               1.35
# 18                      Mongolia               1.33
# 19                   Afghanistan               1.33

# %%
# Maiores taxas de reprodução 

# Configuração do Gráfico
sns.set_style('white')
fig, ax = plt.subplots(figsize=(12,8))

# Gerando o gráfico
splot = sns.barplot(x='reproduction_rate', y='location',
                    data=maiores_r0, ax=ax, orient='h', color='DarkOrange')

for p in splot.patches:
    width = round(p.get_width(),2)
    plt.text(p.get_width()-0.075, p.get_y()+0.55*p.get_height(),
             '{}'.format(width),
             ha='center', va='center', color='white', size=12)
    

ax.set_title('Maiores taxas de reprodução do vírus(R0)\n\n', loc='left', size=22, color='grey')
plt.suptitle('Em 14 de Junho de 2021', x=0.299, y=0.940, color='gray', size=12)

ax.set_xlabel([], color='white')
ax.set_ylabel([], color='white')
ax.set_xticklabels([])

sns.despine(left=True, bottom=True)

plt.tight_layout()

# %% [markdown]
# Os países acima são os países com as maiores taxas de **R0** na data estipulada, onde a doença ainda está se espalhando pela população.

# %%
menores_r0 = (df.loc[(df.date == '2021-06-14') & (df.continent.notnull())]
              .sort_values(by='reproduction_rate', ascending=True)[:20])

menores_r0 = (menores_r0.sort_values(by='reproduction_rate', ascending=False)
              [['location', 'reproduction_rate']].reset_index(drop=True).copy())

menores_r0
# Out:
#                     location  reproduction_rate
# 0                    Czechia               0.59
# 1                       Chad               0.58
# 2                    Romania               0.56
# 3                   Djibouti               0.55
# 4                      Malta               0.54
# 5                     Poland               0.52
# 6                 Azerbaijan               0.50
# 7                      Congo               0.49
# 8   Central African Republic               0.48
# 9          Equatorial Guinea               0.43
# 10                  Cameroon               0.39
# 11       Antigua and Barbuda               0.33
# 12               South Sudan               0.27
# 13                San Marino               0.12
# 14                 Nicaragua               0.06
# 15                  Dominica               0.04
# 16                   Iceland               0.02
# 17                Tajikistan              -0.00
# 18                   Grenada               0.00
# 19                  Tanzania              -0.00

# %%
# Menores taxas de reprodução 

# Configuração do Gráfico
sns.set_style('white')
fig, ax = plt.subplots(figsize=(12,8))

# Gerando o gráfico
splot = sns.barplot(x='reproduction_rate', y='location', 
                    data=menores_r0, ax=ax, orient='h', color='DarkOrange')

for p in splot.patches:
    width = round(p.get_width(),2)

    if width < 0.02:
        plt.text(p.get_width()+0.010, p.get_y()+0.55*p.get_height(),
                '{}'.format(width),
                ha='center', va='center', color='grey', size=10)
        
    elif width == 0.02:
            plt.text(p.get_width()-0.010, p.get_y()+0.55*p.get_height(),
                '{}'.format(width),
                ha='center', va='center', color='white', size=10)
    
    else:
        plt.text(p.get_width()-0.015, p.get_y()+0.55*p.get_height(),
            '{}'.format(width),
            ha='center', va='center', color='white', size=10)


ax.set_title('Menores taxas de reprodução do vírus (R0)\n\n', loc='left', size=22, color='grey')
plt.suptitle('Em 14 de Junho de 2021', x=0.260, y=0.940, color='gray', size=12)

ax.set_xlabel([], color='white')
ax.set_ylabel([], color='white')
ax.set_xticklabels([])

sns.despine(left=True, bottom=True)

plt.tight_layout()

# %% [markdown]
# Os países acima são os países com a epidemia "controlada" devido ao R0 ser menor do que 1, entretanto, vamos investigar os países com a taxa de R0 mais aproximadas de 0.

# %%
menores_r0 = (df.loc[(df.date == "2021-06-14") & 
                     (df.continent.notnull()) & 
                     (df.reproduction_rate <= 0.10)].sort_values(by='reproduction_rate', ascending=False))

menores_r0.loc[:, ['location', 'new_cases', 'new_deaths', 'total_cases', 'total_deaths', 'reproduction_rate']].reset_index(drop=True)
# Out:
#      location  new_cases  ...  total_deaths  reproduction_rate
# 0   Nicaragua        0.0  ...         188.0               0.06
# 1    Dominica        0.0  ...           NaN               0.04
# 2     Iceland        0.0  ...          29.0               0.02
# 3     Grenada        0.0  ...           1.0               0.00
# 4  Tajikistan        0.0  ...          90.0              -0.00
# 5    Tanzania        0.0  ...          21.0              -0.00
#
# [6 rows x 6 columns]

# %% [markdown]
# Ao que parece, os países citados com as menores taxas de reprodução do vírus estão com a epidemia controlada, visto que todos eles possuem registros de casos e mortes, com excessão da Dominica que não divulgou os dados sobre o total de óbitos e novos óbitos, não há novos registros de casos e mortes na data de **14 de Junho de 2021** para os países citados acima.
#
# O que nos leva a pensar que, se realmente esses países que não registraram novos casos ou mortes estão sofrendo o efeito da subnotificação, onde os novos casos não foram contabilizados ou registrados, seja por falta de testes ou por má gestão federal, ou se simplesmente não estão mais disponibilizando esses dados para o público.
#
# Mas como cada país possui suas peculiaridades, protocolos e capacidades diferentes para o enfrentamento da pandemia, é recomendado uma análise futura mais detalhada sobre esses países.

# %% [markdown]
# #### **Número de Testes vs. Taxa de Positividade**
#
#
#
# Os números de casos são contabilizados quando o resultado de um teste é **positivo**.
#
# Os números de testes flutuam bastante devido ao local onde os testes são feitos e a quando os laboratórios reportam o resultado dos testes pois um surto repentino de testes pode refletir em um número de testes feitos em um único dia em grupos específicos como casas de repouso ou prisões e etc. durante um surto, o fato de que os laboratórios e hospitais reportam os resultados de testes apenas em dias da semana então é comum que os números de caiam durante os fins de semanas.
#
# A taxa de positividade indica o quão difícil ou fácil será encontrar um caso, no qual reflete tanto a disseminação e o quão generalizado os testes são.
#
# * **Exemplo**: _Se uma taxa de positividade for 20%, significa que não precisaremos procurar muito para encontrar um caso, quando a taxa for 1% significa que deverá ser feito muitos testes para encontrar um caso positivo._
#
#
# > **Quanto mais a COVID-19 espalhar, maior será a taxa de positividade**
#
# Entretanto, deve-se ater ao contexto, pois se uma taxa de positividade for 60%, pode nos indicar que os testes estejam sendo feitos apenas em hospitais onde os casos serão mais óbvios e não estão sendo feitos na população em geral onde os casos sejam mais leves.
#
#
# Primeiro, veremos os números sobre a testagem nos últimos 7 dias (média móvel) e depois checaremos as informações sobre o número de testes por caso e a taxa de positividade dos países que possuem essa informações disponibilizadas.
#
# Veremos agora as informações sobre novos testes feitos.

# %%
# Média móvel de novos testes

novos_testes = (df.loc[(df.date == "2021-06-14") & (df.continent.notnull())]
                      [["location", "new_tests_smoothed"]].sort_values(by="new_tests_smoothed",
                                                                       ascending=False)[:20])

novos_testes.reset_index(drop=True)
# Out:
#                 location  new_tests_smoothed
# 0                  India           1898645.0
# 1                 Russia            354452.0
# 2   United Arab Emirates            233552.0
# 3                 Turkey            221453.0
# 4                  Italy            181716.0
# 5                Czechia            136337.0
# 6                   Iran            125649.0
# 7               Malaysia             86909.0
# 8                 Canada             66880.0
# 9                  Chile             65786.0
# 10             Indonesia             63875.0
# 11             Singapore             63179.0
# 12                 Japan             62370.0
# 13             Australia             56033.0
# 14              Slovakia             53704.0
# 15          South Africa             46236.0
# 16                Cyprus             42227.0
# 17              Pakistan             40624.0
# 18           South Korea             29472.0
# 19                Taiwan             25852.0

# %%
# Gráfico da média móvel de novos testes 

# Configuração do Gráfico
sns.set_style('white')
fig, ax = plt.subplots(figsize=(12,8))

# Gerando o gráfico
splot = sns.barplot(x='new_tests_smoothed', y='location',
                    data=novos_testes, ax=ax, orient='h', color='DarkOrange')

for p in splot.patches:
    width = round(p.get_width()/1000000, 2)
    
    plt.text(p.get_width()+70000, p.get_y()+0.55*p.get_height(),
             '{}M'.format(width),
             ha='center', va='center', color='DarkOrange', size=12, fontweight="bold")
   

ax.set_title('Novos testes realizados (média móvel)\n\n', loc='left', size=20, color='grey')
plt.suptitle('Em 14 de Junho de 2021', x=0.250, y=0.940, color='gray', size=12)

ax.set_xlabel([], color='white')
ax.set_ylabel([], color='white')
ax.set_xticklabels([])

sns.despine(left=True, bottom=True)

plt.tight_layout()

# %% [markdown]
# A Índia é o país que mais fez testes em média na data estipulada, provavelmente devido a aparição da nova variante [Delta](https://www.uol.com.br/vivabem/noticias/afp/2021/06/11/variante-delta-do-coronavirus-e-60-mais-contagiosa-afirmam-autoridades-britanicas.htm) do coronavírus que é mais contagiosa e surgiu no território indiano mas que já espalhou para outros países.
#
# Podemos também ver a quantidade de testes feitos para cada encontrar um novo caso positivo para nos situar a cerca da situação da infecção nos países.

# %%
# Testes por casos
# Quantos testes precisam ser feitos para encontrar um caso positivo

testes_por_caso = (df.loc[(df.date == "2021-06-14") & (df.continent.notnull()) &
                          (df.tests_per_case.notnull()), ["location", "tests_per_case"]].sort_values(by="tests_per_case", ascending=True))

testes_por_caso = testes_por_caso.sort_values(by="tests_per_case", ascending=False).copy()

testes_por_caso.reset_index(drop=True)
# Out:
#                   location  tests_per_case
# 0                Australia          5768.3
# 1                Singapore          4859.9
# 2              New Zealand          1618.4
# 3                   Israel          1364.6
# 4                    Malta          1051.6
# 5                  Czechia          1000.0
# 6                   Cyprus           761.8
# 7                 Slovakia           333.3
# 8                     Laos           262.5
# 9                  Nigeria           194.5
# 10         North Macedonia           149.2
# 11                 Romania           133.5
# 12              Azerbaijan           121.9
# 13                  Taiwan           112.1
# 14    United Arab Emirates           110.6
# 15                   Italy           105.3
# 16                 Moldova           100.7
# 17                Bulgaria            95.6
# 18                 Hungary            77.7
# 19                    Togo            66.9
# 20                 Estonia            65.1
# 21                  Belize            62.7
# 22             South Korea            58.0
# 23                  Serbia            53.1
# 24                  Latvia            53.1
# 25                  Canada            52.5
# 26  Bosnia and Herzegovina            48.5
# 27                  Turkey            36.5
# 28                Pakistan            35.5
# 29                   Japan            35.3
# 30                 Croatia            34.5
# 31                 Senegal            33.5
# 32                   Qatar            29.0
# 33                  Russia            29.0
# 34                Ethiopia            27.6
# 35                  Rwanda            26.3
# 36                 Morocco            24.0
# 37                   India            23.1
# 38                Slovenia            18.2
# 39                 Belarus            17.9
# 40                 Ukraine            17.0
# 41                Malaysia            15.1
# 42                Maldives            14.6
# 43                 Myanmar            13.2
# 44                    Iran            12.9
# 45                 Bahrain            12.5
# 46                Cambodia            11.6
# 47               Palestine            10.1
# 48               Indonesia             7.9
# 49              Bangladesh             7.5
# 50               Sri Lanka             7.2
# 51                 Uruguay             6.4
# 52            South Africa             6.1
# 53                 Tunisia             3.6
# 54                   Nepal             3.6
# 55                 Namibia             3.0

# %%
# Gráfico de mais casos por testes

# Configuração do Gráfico
sns.set_style('white')
fig, ax = plt.subplots(figsize=(12,8))

# Gerando o gráfico
splot = sns.barplot(x='tests_per_case', y='location',
                    data=testes_por_caso[-20:], ax=ax, orient='h', color='DarkOrange')

for p in splot.patches:
    width = round(p.get_width())
    plt.text(p.get_width()-0.35, p.get_y()+0.55*p.get_height(),
             '{}'.format(width),
             ha='center', va='center', color='white', size=12)
    

ax.set_title('Países com menos testes por caso (média móvel)\n\n', loc='left', size=20, color='grey')
plt.suptitle('Em 14 de Junho de 2021', x=0.193, y=0.940, color='gray', size=12)

ax.set_xlabel([], color='white')
ax.set_ylabel([], color='white')
ax.set_xticklabels([])

sns.despine(left=True, bottom=True)

plt.tight_layout()

# %% [markdown]
# Para a data estipula, boa parte dos países ainda não haviam divulgado os dados sobre os testes por caso, mas para explicar o que são os _testes por caso_, os países que divulgaram os dados até agora servirão de exemplo.
#
# Os países no gráfico acima são aqueles que precisam de menos testes para encontrar um caso positivo, por exemplo:
#
# * **No Uruguai, a cada 6 _testes_ feitos em média durante os últimos 7 dias, 1 retornará _positivo_**
#
# Isso pode nos indicar que a doença ainda está se espalhando por esses países de forma acelerada.

# %%
# Gráfico de mais testes por casos

# Configuração do Gráfico
sns.set_style('white')
fig, ax = plt.subplots(figsize=(12,8))

# Gerando o gráfico
splot = sns.barplot(x='tests_per_case', y='location',
                    data=testes_por_caso[:10], ax=ax, orient='h', color='DarkOrange')

for p in splot.patches:
    width = round(p.get_width())
    plt.text(p.get_width()+200, p.get_y()+0.55*p.get_height(),
             '{}'.format(width),
             ha='center', va='center', color='DarkOrange', size=14)
    

ax.set_title('Países com mais testes por caso (média móvel)\n\n', loc='left', size=20, color='grey')
plt.suptitle('Em 14 de Junho de 2021', x=0.200, y=0.940, color='gray', size=12)

ax.set_xlabel([], color='white')
ax.set_ylabel([], color='white')
ax.set_xticklabels([])

sns.despine(left=True, bottom=True)

plt.tight_layout()

# %% [markdown]
# Pode-se observar que alguns países precisam fazer muitos testes para encontrar um novo caso, como é o caso da __Autrália__ e __Singapura__ que precisam de mais de 4000 testes para encontrar 1 caso positivo e logo em seguida a __Nova Zelândia__, __Israel__, __Malta__ e __República Tcheca__, ambas precisando de mais de 1000 testes para encontrar um caso novo.
#
# Também podemos inferir que os países citados acima podem estar com a COVID-19 controlada em seus territórios, usando como exemplo:
# > __A Austrália precisa, em média, fazer 5768 testes em uma semana para encontrar 1 caso positivo de infecção por COVID-19.__
#
#
# A __taxa de positividade__ é a porcentagem de testes feitos que retornam o resultado positivo para a infecção por COVID-19, entretanto, nem todos os países possuem os dados sobre a taxa de positividade então usaremos aqueles nos quais possuímos conhecimento de tais dados.

# %%
# Selecionando a taxa de positividade dos países

taxa_positividade = (df.loc[(df.date == "2021-06-14") &
                            (df.continent.notnull()) & 
                            (df.positive_rate.notnull()), ["location", "positive_rate"]]
                     .sort_values(by="positive_rate", ascending=False))

taxa_positividade['positive_rate'] = taxa_positividade['positive_rate'].copy() * 100

taxa_positividade
# Out:
#                      location  positive_rate
# 60362                 Namibia           33.5
# 88400                 Tunisia           28.1
# 60932                   Nepal           27.5
# 79809            South Africa           16.3
# 91951                 Uruguay           15.6
# 82245               Sri Lanka           13.8
# 7886               Bangladesh           13.4
# 40671               Indonesia           12.6
# 66925               Palestine            9.9
# 15056                Cambodia            8.6
# 7416                  Bahrain            8.0
# 41649                    Iran            7.7
# 59903                 Myanmar            7.6
# 53763                Maldives            6.8
# 53298                Malaysia            6.6
# 89974                 Ukraine            5.9
# 8816                  Belarus            5.6
# 78610                Slovenia            5.5
# 40200                   India            4.3
# 59006                 Morocco            4.2
# 72196                  Rwanda            3.8
# 28875                Ethiopia            3.6
# 70759                   Qatar            3.5
# 71737                  Russia            3.4
# 75720                 Senegal            3.0
# 21315                 Croatia            2.9
# 66457                Pakistan            2.8
# 44704                   Japan            2.8
# 88862                  Turkey            2.7
# 11775  Bosnia and Herzegovina            2.1
# 16030                  Canada            1.9
# 76196                  Serbia            1.9
# 48539                  Latvia            1.9
# 80801             South Korea            1.7
# 9764                   Belize            1.6
# 87429                    Togo            1.5
# 27956                 Estonia            1.5
# 39222                 Hungary            1.3
# 13645                Bulgaria            1.0
# 56995                 Moldova            1.0
# 85111                  Taiwan            0.9
# 90478    United Arab Emirates            0.9
# 43731                   Italy            0.9
# 6481               Azerbaijan            0.8
# 71235                 Romania            0.7
# 64383         North Macedonia            0.7
# 63396                 Nigeria            0.5
# 48059                    Laos            0.4
# 78110                Slovakia            0.3
# 22321                  Cyprus            0.1
# 62015             New Zealand            0.1
# 22793                 Czechia            0.1
# 54707                   Malta            0.1
# 43228                  Israel            0.1
# 77607               Singapore            0.0
# 5532                Australia            0.0

# %%
# Gráfico das maiores taxas de positividade

# Configuração do Gráfico
sns.set_style('white')
fig, ax = plt.subplots(figsize=(12,8))

# Gerando o gráfico
splot = sns.barplot(x='positive_rate', y='location',
                    data=taxa_positividade[:20], ax=ax, orient='h', color='DarkOrange')

for p in splot.patches:
    width = round(p.get_width(),2)
    plt.text(p.get_width()+1.10, p.get_y()+0.55*p.get_height(),
             '{}%'.format(width),
             ha='center', va='center', color='DarkOrange', size=12)
    

ax.set_title('Maiores taxas de positividade\n\n', loc='left', size=22, color='grey')
plt.suptitle('Em 14 de Junho de 2021', x=0.193, y=0.940, color='gray', size=12)

ax.set_xlabel([], color='white')
ax.set_ylabel([], color='white')
ax.set_xticklabels([])

sns.despine(left=True, bottom=True)

plt.tight_layout()

# %%
# Gráfico das menores taxas de positividade

# Configuração do Gráfico
sns.set_style('white')
fig, ax = plt.subplots(figsize=(12,8))

# Gerando o gráfico
splot = sns.barplot(x='positive_rate', y='location',
                    data=taxa_positividade[-20:], ax=ax, orient='h', color='DarkOrange')

for p in splot.patches:
    width = round(p.get_width(),3)

 
    plt.text(p.get_width()+0.05, p.get_y()+0.55*p.get_height(),
            '{}%'.format(width),
            ha='center', va='center', color='DarkOrange', size=12)



ax.set_title('Menores taxas de positividade\n\n', loc='left', size=22, color='grey')
plt.suptitle('Em 14 de Junho de 2021', x=0.25, y=0.940, color='gray', size=12)

ax.set_xlabel([], color='white')
ax.set_ylabel([], color='white')
ax.set_xticklabels([])

sns.despine(left=True, bottom=True)

plt.tight_layout()

# %% [markdown]
# Uma observação interessante que podemos fazer é em relação aos números da Índia para o dia **14 de Junho de 2021**, o país aparece com um número muito grande de casos registrados, é o país que mais está fazendo testes no mundo, possui uma taxa de 1 caso a cada 23 testes feitos mas a média móvel da taxa de positividade é baixa em relação aos números anteriores e na definição da taxa de positividade, significa é muito difícil encontrar um caso e que deve ser feitos muitos testes para encontrar um caso novo.
#
# Cabe aqui, uma abertura para uma análise mais aprofundada sobre esse caso específico, entretanto, este não é nosso foco agora.
#
# Feito a análise da perspectiva global, podemos dar início a análise da situação brasileira.
#
#
# ---

# %% [markdown]
# ### **Análise Exploratória para o Brasil**
#
#
# <img src="https://image.freepik.com/fotos-gratis/tema-covid-19-pandemico-mulher-em-luvas-de-protecao-mascara-facial-medica-segura-a-bandeira-do-brasil-isolada-no-branco_175682-16140.jpg" width=75%>
#
# Para analisar os dados brasileiros usaremos os dois datasets:
#
# * **[OWID](https://raw.githubusercontent.com/roberto-paixao/analise_covid_mundial/main/data/owid-covid-data.csv)**: Para análise sobre a situação geral do Brasil
# * **[WCOTA](https://raw.githubusercontent.com/roberto-paixao/analise_covid_mundial/main/data/wcota_brazil_dataset.csv)**: Para análise dos estados brasileiros.
#
#
# Primeiro, vamos criar o dataset dos estados brasileiros, em seguida verificaremos o escopo do dataset e seus atributos e se os mesmos precisarão de tratamento.

# %% [markdown]
# * Criar uma cópia do DataFrame apenas com o Brasil
#     * `df_brasil = df.loc[df.location == "Brazil"].copy()`
# * Identificar quando foi registrada a primeira morte no Brasil
# * Identificar quantos dias demorou para registrarmos a primeira morte, considerando o primeiro caso de COVID-19 registrado.
# * Plotar gráficos de linha em escalas linear e logarítmica para os casos totais e mortes totais.

# %%
# Dataset dos estados brasileiros
DATA_PATH = "https://raw.githubusercontent.com/roberto-paixao/analise_covid_mundial/main/data/wcota_brazil_dataset.csv"

df_estados = pd.read_csv(DATA_PATH)

df_brasil = df.loc[df.location == "Brazil"].copy()

# %%
# Verificando as primeiras linhas do dataset

df_estados.head(10)
# Out:
#    epi_week  ... vaccinated_second_per_100k_inhabitants
# 0         9  ...                                    NaN
# 1         9  ...                                    NaN
# 2         9  ...                                    NaN
# 3         9  ...                                    NaN
# 4         9  ...                                    NaN
# 5         9  ...                                    NaN
# 6         9  ...                                    NaN
# 7         9  ...                                    NaN
# 8         9  ...                                    NaN
# 9         9  ...                                    NaN
#
# [10 rows x 22 columns]

# %%
df_estados.tail(10)
# Out:
#        epi_week  ... vaccinated_second_per_100k_inhabitants
# 12884       124  ...                            10915.74991
# 12885       124  ...                            11125.01722
# 12886       124  ...                             7974.22949
# 12887       124  ...                            10465.01838
# 12888       124  ...                            14367.38738
# 12889       124  ...                            10708.13261
# 12890       124  ...                             9437.61159
# 12891       124  ...                            13019.06971
# 12892       124  ...                             8765.20950
# 12893       124  ...                            11348.12612
#
# [10 rows x 22 columns]

# %%
df_estados.sample(10)
# Out:
#        epi_week  ... vaccinated_second_per_100k_inhabitants
# 6991         47  ...                                    NaN
# 826          15  ...                                    NaN
# 8821        103  ...                                    NaN
# 6407         44  ...                                    NaN
# 7906         51  ...                                    NaN
# 4311         33  ...                                    NaN
# 1981         21  ...                                    NaN
# 2160         22  ...                                    NaN
# 10720       113  ...                             2373.96174
# 12382       121  ...                             7299.30088
#
# [10 rows x 22 columns]

# %%
# Informações gerais sobre o dataset WCOTA

df_estados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12894 entries, 0 to 12893
# Data columns (total 22 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   epi_week                                12894 non-null  int64
#  1   date                                    12894 non-null  object
#  2   country                                 12894 non-null  object
#  3   state                                   12894 non-null  object
#  4   city                                    12894 non-null  object
#  5   newDeaths                               12894 non-null  int64
#  6   deaths                                  12894 non-null  int64
#  7   newCases                                12894 non-null  int64
#  8   totalCases                              12894 non-null  int64
#  9   deathsMS                                12894 non-null  int64
#  10  totalCasesMS                            12894 non-null  int64
#  11  deaths_per_100k_inhabitants             12894 non-null  float64
#  12  totalCases_per_100k_inhabitants         12894 non-null  float64
#  13  deaths_by_totalCases                    12894 non-null  float64
#  14  recovered                               12251 non-null  float64
#  15  suspects                                10350 non-null  float64
#  16  tests                                   11550 non-null  float64
#  17  tests_per_100k_inhabitants              11550 non-null  float64
#  18  vaccinated                              4163 non-null   float64
#  19  vaccinated_per_100k_inhabitants         4163 non-null   float64
#  20  vaccinated_second                       3483 non-null   float64
#  21  vaccinated_second_per_100k_inhabitants  3483 non-null   float64
# dtypes: float64(11), int64(7), object(4)
# memory usage: 2.2+ MB

# %% [markdown]
# Alguns atributos estão com menos dados do que o restante dos atributos e devem ser investigados.

# %%
# Calculando a porcentagem faltante do dataset WCOTA

round(df_estados.isnull().mean().sort_values(ascending=False) * 100, 2)
# Out:
# vaccinated_second_per_100k_inhabitants    72.99
# vaccinated_second                         72.99
# vaccinated_per_100k_inhabitants           67.71
# vaccinated                                67.71
# suspects                                  19.73
# tests_per_100k_inhabitants                10.42
# tests                                     10.42
# recovered                                  4.99
# deaths                                     0.00
# date                                       0.00
# country                                    0.00
# state                                      0.00
# city                                       0.00
# newDeaths                                  0.00
# totalCasesMS                               0.00
# newCases                                   0.00
# totalCases                                 0.00
# deathsMS                                   0.00
# deaths_per_100k_inhabitants                0.00
# totalCases_per_100k_inhabitants            0.00
# deaths_by_totalCases                       0.00
# epi_week                                   0.00
# dtype: float64

# %% [markdown]
# Como a vacinação no Brasil começou a alguns meses atrás, é esperado que os dados faltantes sobre essas informações sejam relativamente altos.

# %%
# Verificando os tipos do atributos.

df_estados.dtypes
# Out:
# epi_week                                    int64
# date                                       object
# country                                    object
# state                                      object
# city                                       object
# newDeaths                                   int64
# deaths                                      int64
# newCases                                    int64
# totalCases                                  int64
# deathsMS                                    int64
# totalCasesMS                                int64
# deaths_per_100k_inhabitants               float64
# totalCases_per_100k_inhabitants           float64
# deaths_by_totalCases                      float64
# recovered                                 float64
# suspects                                  float64
# tests                                     float64
# tests_per_100k_inhabitants                float64
# vaccinated                                float64
# vaccinated_per_100k_inhabitants           float64
# vaccinated_second                         float64
# vaccinated_second_per_100k_inhabitants    float64
# dtype: object

# %% [markdown]
# O dataset do WCOTA também possui um atributo `date`, porém está com o formato `object` e precisa ser convertido para `datetime` para podermos trabalhar com as datas.

# %%
# Convertendo a coluna date para o formato datetime

df_estados.date = pd.to_datetime(df_estados.date)

# %%
df_estados.date.max()
# Out:
# Timestamp('2021-06-15 00:00:00')

# %% [markdown]
# ####  **Evolução dos casos e óbitos no país**
#
# Aqui criaremos um novo dataset com somente os dados relacionados ao Brasil, e junto com o dataset __wcota__ (`df_estados`), poderemos obter _insights_ sobre o Brasil.
#
# Antes de tudo, vamos ver o progresso da doença analisando a média móvel dos novos casos no Brasil.

# %%
# Amostra dos dados referentes ao Brasil

df_brasil.sample(10)
# Out:
#       iso_code      continent  ... human_development_index excess_mortality
# 12239      BRA  South America  ...                   0.765              NaN
# 12331      BRA  South America  ...                   0.765              NaN
# 12657      BRA  South America  ...                   0.765              NaN
# 12564      BRA  South America  ...                   0.765              NaN
# 12532      BRA  South America  ...                   0.765              NaN
# 12253      BRA  South America  ...                   0.765              NaN
# 12280      BRA  South America  ...                   0.765              NaN
# 12267      BRA  South America  ...                   0.765              NaN
# 12519      BRA  South America  ...                   0.765              NaN
# 12322      BRA  South America  ...                   0.765              NaN
#
# [10 rows x 60 columns]

# %%
# Porcentagem de dados faltantes nos atributos

round(df_brasil.isnull().mean() * 100, 2).sort_values(ascending=False)
# Out:
# weekly_icu_admissions_per_million        100.00
# weekly_icu_admissions                    100.00
# new_tests_per_thousand                   100.00
# new_tests                                100.00
# weekly_hosp_admissions_per_million       100.00
# weekly_hosp_admissions                   100.00
# tests_per_case                           100.00
# positive_rate                            100.00
# hosp_patients_per_million                100.00
# hosp_patients                            100.00
# handwashing_facilities                   100.00
# icu_patients_per_million                 100.00
# icu_patients                             100.00
# excess_mortality                          96.64
# total_tests                               96.43
# total_tests_per_thousand                  96.43
# new_tests_smoothed_per_thousand           82.77
# new_tests_smoothed                        82.77
# tests_units                               79.41
# people_fully_vaccinated                   76.47
# people_fully_vaccinated_per_hundred       76.47
# new_vaccinations                          73.95
# total_vaccinations_per_hundred            72.06
# people_vaccinated                         72.06
# total_vaccinations                        72.06
# people_vaccinated_per_hundred             72.06
# new_vaccinations_smoothed                 68.49
# new_vaccinations_smoothed_per_million     68.49
# total_deaths                               4.20
# total_deaths_per_million                   4.20
# new_deaths_per_million                     4.20
# new_deaths                                 4.20
# reproduction_rate                          3.78
# new_cases_smoothed_per_million             1.05
# new_deaths_smoothed                        1.05
# new_deaths_smoothed_per_million            1.05
# new_cases_smoothed                         1.05
# stringency_index                           1.05
# new_cases                                  0.00
# total_cases_per_million                    0.00
# total_cases                                0.00
# new_cases_per_million                      0.00
# location                                   0.00
# continent                                  0.00
# date                                       0.00
# female_smokers                             0.00
# life_expectancy                            0.00
# hospital_beds_per_thousand                 0.00
# male_smokers                               0.00
# diabetes_prevalence                        0.00
# cardiovasc_death_rate                      0.00
# extreme_poverty                            0.00
# gdp_per_capita                             0.00
# aged_70_older                              0.00
# aged_65_older                              0.00
# median_age                                 0.00
# population_density                         0.00
# human_development_index                    0.00
# population                                 0.00
# iso_code                                   0.00
# dtype: float64

# %% [markdown]
# Como esperado, não há dados sobre hospitalizações e internações em UTIs no Brasil. Vale ressaltar que também não está disponibilizado os dados sobre `tests_per_case` e `positive_rate` que foram utilizados na análise mundial anterior.

# %%
# Gráfico de média móvel de novos casos

sns.set_style('ticks')
fig, ax = plt.subplots(figsize=(12,8))

novos_casos_brasil = (df_brasil.loc[:, ['date', 'new_cases_smoothed_per_million']].reset_index(drop=True))

novos_casos_mundial = (df.loc[df.location == 'World', ['date', 'new_cases_smoothed_per_million']].reset_index(drop=True))

sns.lineplot(x='date', y='new_cases_smoothed_per_million',
             data=novos_casos_brasil, ci=None, linewidth=2, color='DarkOrange')

sns.lineplot(x='date', y='new_cases_smoothed_per_million',
             data=novos_casos_mundial, ci=None, linewidth=1.2, color='Gray')


ax.set_title('Média móvel (7 dias) de novos casos no Brasil\n\n', color='Grey', size=20, loc='left')
plt.suptitle('normalizados por milhão de habitantes', x=0.218, y=0.950, color='Grey', size=14)

ax.text(x=737960.4, y=340, s='Brasil', color='DarkOrange', fontweight='bold', size=14)
ax.text(x=737960.4, y=45, s='Mundo', color='Gray', size=12)

ax.set_xlabel([], color='white')
ax.set_ylabel([], color='white')


sns.despine()
plt.tight_layout()

# %% [markdown]
# Analisando o gráfico, vemos que os números de casos do Brasil passou pela "primeira onda" de casos e segue para a "segunda onda" de casos, com uma taxa de novos casos maior que a média móvel mundial.

# %%
# Gráfico de média móvel de novos obitos

sns.set_style('ticks')
fig, ax = plt.subplots(figsize=(12,8))

novos_obitos_brasil = (df_brasil.loc[:, ['date', 'new_deaths_smoothed_per_million']].reset_index(drop=True))
novos_obitos_mundial = (df.loc[df.location == 'World', ['date', 'new_deaths_smoothed_per_million']].reset_index(drop=True))

sns.lineplot(x='date', y='new_deaths_smoothed_per_million',
             data=novos_obitos_brasil, ci=None, linewidth=2, color='DarkOrange')

sns.lineplot(x='date', y='new_deaths_smoothed_per_million',
             data=novos_obitos_mundial, ci=None, linewidth=1.2, color='Gray')


ax.set_title('Média móvel (7 dias) de novos óbitos no Brasil\n\n', color='Grey', size=20, loc='left')
plt.suptitle('normalizados por milhão de habitantes', x=0.190, y=0.945, color='Grey', size=12)

ax.set_xlabel([], color='white')
ax.set_ylabel([], color='white')

ax.text(x=737960.4, y=9.2, s='Brasil', color='DarkOrange', fontweight='bold', size=14)
ax.text(x=737960.4, y=1.25, s='Mundo', color='Gray', size=12)

sns.despine()
plt.tight_layout()

# %% [markdown]
# Utilizando os valores normalizados (por milhão de habitantes) para remover o efeito da população, o Brasil aparece com uma média móvel de óbitos muito maior do que o resto do mundo.

# %%
# Total de casos até 14/06/2021

df_brasil.total_cases[-1:]
# Out:
# 12695    17533221.0
# Name: total_cases, dtype: float64

# %%
# Total de óbitos até 14/06/2021

df_brasil.total_deaths[-1:]
# Out:
# 12695    490696.0
# Name: total_deaths, dtype: float64

# %%
# Texto com as informações sobre Casos e Óbitos

fig, ax = plt.subplots(ncols=2, figsize=(12,3))


ax[0].text(0.0, 1, s='17.5M', size=80, color='DarkOrange', fontweight='bold')
ax[0].text(0.0, 0.600, s='casos foram registrados\naté 14 de Junho de 2021.', size=20, color='grey')

ax[1].text(0.0, 1, s='490 mil', size=80, color='DarkOrange', fontweight='bold')
ax[1].text(0.0, 0.600, s='óbitos foram registrados\naté 14 de Junho de 2021.', size=20, color='grey')

ax[0].xaxis.set_visible(False)
ax[0].yaxis.set_visible(False)

ax[1].xaxis.set_visible(False)
ax[1].yaxis.set_visible(False)

sns.despine(left=True, bottom=True)
plt.tight_layout()

# %% [markdown]
# Até a data de **14 de Junho de 2021** foram registrados 17.533.221 milhões de casos e 490.696 óbitos decorrente da COVID-19.

# %% [markdown]
# #### **Taxa de reprodução (R0) do vírus no país**
#
# No dataset **OWID** temos uma estimativa do R0 do Brasil, vamos ver isso agora.

# %%
# Gráfico da taxa de reprodução

sns.set_style('ticks')
fig, ax = plt.subplots(figsize=(12,8))

taxa_reproducao_brasil = (df_brasil.loc[:, ['date', 'reproduction_rate']].reset_index(drop=True))
taxa_reproducao_mundial = (df.loc[df.location == 'World', ['date', 'reproduction_rate']]).reset_index(drop=True)

sns.lineplot(x='date', y='reproduction_rate',
             data=taxa_reproducao_brasil, ci=None, linewidth=3, color='DarkOrange')

sns.lineplot(x='date', y='reproduction_rate',
                    data=taxa_reproducao_mundial, ci=None, ax=ax, linewidth=1.3, color='Gray')

ax.set_title('Taxa de Reprodução do vírus no Brasil\n\n', color='Grey', size=20, loc='left')

ax.text(x=737960.4, y=1.03, s='Brasil', color='DarkOrange', fontweight='bold', size=12)
ax.text(x=737960.4, y=0.87, s='Mundo', color='Gray')

ax.set_xlabel([], color='white')
ax.set_ylabel([], color='white')



sns.despine()
plt.tight_layout()

# %%
df_brasil.loc[(df_brasil.date == '2021-06-14'), ['reproduction_rate']]
# Out:
#        reproduction_rate
# 12694               1.05

# %%
fig, ax = plt.subplots(figsize=(5,3))


ax.text(0.0, 1, s='1.05', size=80, color='DarkOrange', fontweight='bold')
ax.text(0.0, 0.600, s='é a Taxa de Reprodução (R0)\ndo vírus no Brasil.', size=20, color='grey')

sns.despine(left=True, bottom=True)
ax.xaxis.set_visible(False)
ax.yaxis.set_visible(False)
plt.tight_layout()

# %% [markdown]
# No dia **14 de Junho de 2021** a taxa de reprodução do vírus (R0) no Brasil era de 1.05, ou seja, uma pessoa infectada transmitiria o vírus para outras 1.05 pessoas.
#
# E seguindo a regra de que quando o R0 for maior que 1, significa que a doença ainda está espalhando pelo país, no caso do Brasil, apesar de baixa, ainda está se espalhando ou que está perto de ser controlada.

# %% [markdown]
# #### **Situação dos Estados**
#
# Nesta etapa, analisaremos a situação dos estados em relação aos números de casos, óbitos e como está o progresso da vacinação nos estados.

# %%
# Filtrando os dados dos estados.

df_estados = df_estados.loc[(df_estados.date != "2021-06-15") & (df_estados.state != "TOTAL")].copy()
df_estados
# Out:
#        epi_week  ... vaccinated_second_per_100k_inhabitants
# 0             9  ...                                    NaN
# 2             9  ...                                    NaN
# 4             9  ...                                    NaN
# 6             9  ...                                    NaN
# 8             9  ...                                    NaN
# ...         ...  ...                                    ...
# 12860       124  ...                            14329.29378
# 12861       124  ...                            10681.25114
# 12862       124  ...                             9178.81268
# 12863       124  ...                            12991.18586
# 12864       124  ...                             8738.37949
#
# [12390 rows x 22 columns]

# %%
# Selecionando os dados de casos totais

casos_totais_estados = (df_estados.loc[(df_estados.date == "2021-06-14"), ["state", "totalCases"]]
                        .sort_values(by="totalCases", ascending=False))[:10]

casos_totais_estados
# Out:
#       state  totalCases
# 12863    SP     3464158
# 12848    MG     1684962
# 12855    PR     1152368
# 12860    RS     1149424
# 12842    BA     1066552
# 12861    SC     1008059
# 12856    RJ      909341
# 12843    CE      848248
# 12846    GO      641993
# 12851    PA      535640

# %%
# Gráfico de Casos Totais por estado

sns.set_style('white')
fig, ax = plt.subplots(figsize=(12,8))


splot = sns.barplot(x='state', y='totalCases', data=casos_totais_estados, ax=ax, color='DarkOrange')


for p in splot.patches:
    height = p.get_height()

    splot.annotate('{}M'.format(round(p.get_height()/1000000, 2)),
                (p.get_x() + p.get_width()/2, p.get_height()),
                ha='center',
                va='center',
                size=12, 
                color='white', 
                fontweight='bold',
                xytext=(0,-15),
                textcoords='offset points')


ax.set_title('Os 10 estados com mais casos de COVID-19\n', loc='left', size=20, color='grey')

ax.set_xlabel([], color='white')
ax.set_ylabel([], color='white')
ax.set_yticklabels([])
ax.set_xticklabels(casos_totais_estados['state'].to_list(), size=12, color='gray')
sns.despine(left=True, bottom=True)

plt.tight_layout()

# %% [markdown]
# São Paulo segue sendo o estado com mais casos totais de COVID-19 até o momento com 3 milhões e 460 mil casos, um pouco mais que o dobro de Minas Gerais que segue com 1.68 milhões de casos registrados até a data estipulada.

# %%
# Selecionando os dados de óbitos totais por estado

obitos_totais_estados = (df_estados.loc[(df_estados.date == "2021-06-14", ['state', 'deaths'])]
                         .sort_values(by="deaths", ascending=False).copy()[:10])

obitos_totais_estados
# Out:
#       state  deaths
# 12863    SP  118213
# 12856    RJ   53015
# 12848    MG   43154
# 12860    RS   29701
# 12855    PR   28208
# 12842    BA   22601
# 12843    CE   21460
# 12846    GO   18093
# 12853    PE   16860
# 12861    SC   16006

# %%
# Gráfico de total de óbitos registrados por estado

sns.set_style('white')
fig, ax = plt.subplots(figsize=(12,8))


splot = sns.barplot(x='state', y='deaths', data=obitos_totais_estados, ax=ax, color='DarkOrange')


for p in splot.patches:
    height = p.get_height()

    splot.annotate('{} mil'.format(round(p.get_height()/1000, 1)),
                (p.get_x() + p.get_width()/2, p.get_height()),
                ha='center',
                va='center',
                size=10, 
                color='white', 
                fontweight='bold',
                xytext=(0,-15),
                textcoords='offset points')


ax.set_title('Os 10 estados com mais óbitos por COVID-19\n', loc='left', size=20, color='grey')

ax.set_xlabel([], color='white')
ax.set_ylabel([], color='white')
ax.set_yticklabels([])
ax.set_xticklabels(obitos_totais_estados['state'].to_list(), size=12, color='gray')
sns.despine(left=True, bottom=True)

plt.tight_layout()

# %% [markdown]
# Se tratando de números absolutos, São Paulo ainda segue com o maior número de óbitos decorrentes da COVID-19 com 118 mil registros de óbitos até o momento da data estipulada.
#
# Podemos também, ressaltar o detalhe de que o segundo estado com mais registros de óbitos é o Rio de Janeiro sendo que em número de casos o estado aparece em 7ª posição com 910 mil casos registrados. Enquanto Minas Gerais aparece na 3ª posição em óbitos com 43 mil registros, o Rio de Janeiro aparece na 2ª posição com 53 mil óbitos. Isso pode nos indicar que a mortalidade no Rio de Janeiro é muito alta.
#
# Para podermos comparar os estados, eliminando o efeito da população como fizemos anteriormente, usaremos os dados normalizados por 100 mil habitantes.

# %%
# Filtrando os dados de casos normalizados

casos_normalizados = (df_estados.loc[df_estados.date == "2021-06-14", ["state", "totalCases_per_100k_inhabitants"]]
                      .sort_values(by='totalCases_per_100k_inhabitants', ascending=False))[:10]

casos_normalizados.reset_index(drop=True)
# Out:
#   state  totalCases_per_100k_inhabitants
# 0    RR                      17807.68323
# 1    SC                      14069.62774
# 2    DF                      13865.73266
# 3    AP                      13538.93850
# 4    RO                      13451.70139
# 5    ES                      12437.98290
# 6    MT                      12327.77131
# 7    TO                      12024.92774
# 8    MS                      11365.00868
# 9    SE                      10995.49484

# %%
# Gráfico dos casos normalizados

sns.set_style('white')
fig, ax = plt.subplots(figsize=(12,8))


splot = sns.barplot(x='state', y='totalCases_per_100k_inhabitants', data=casos_normalizados, ax=ax, color='DarkOrange')


for p in splot.patches:
    height = p.get_height()

    splot.annotate('{} mil'.format(round(p.get_height()/1000, 2)),
                (p.get_x() + p.get_width()/2, p.get_height()),
                ha='center',
                va='center',
                size=10, 
                color='white', 
                fontweight='bold',
                xytext=(0,-15),
                textcoords='offset points')


ax.set_title('Casos normalizados por 100 mil habitantes\n', loc='left', size=22, color='grey')
# plt.suptitle('normalizados por 100 mil habitantes', size=12, color='grey', x=0.166, y=0.950)

ax.set_xlabel([], color='white')
ax.set_ylabel([], color='white')
ax.set_yticklabels([])
ax.set_xticklabels(casos_normalizados['state'].to_list(), size=12, color='gray')
sns.despine(left=True, bottom=True)

plt.tight_layout()

# %% [markdown]
# Usando os dados normalizados, percebe-se que novos estados apareceram, como por exemplo Roraima que surge como o estado com mais casos por 100 mil habitantes.
#
# A seguir, verificaremos os números de obitos normalizados.

# %%
# Selecionandos os dados normalizados de óbitos

obitos_normalizados = (df_estados.loc[df_estados.date == "2021-06-14", ["state", "deaths_per_100k_inhabitants"]]
                       .sort_values(by="deaths_per_100k_inhabitants", ascending=False)[:10])

obitos_normalizados.reset_index(drop=True)
# Out:
#   state  deaths_per_100k_inhabitants
# 0    RO                    334.45399
# 1    MT                    329.06046
# 2    AM                    317.25642
# 3    RJ                    307.06733
# 4    DF                    297.68498
# 5    ES                    278.02869
# 6    RR                    277.33710
# 7    MS                    272.36553
# 8    RS                    261.05631
# 9    GO                    257.79549

# %%
# Gráfico de óbitos normalizados


# Configuração de Gráfico
sns.set_style('white')
fig, ax = plt.subplots(figsize=(12,8))
# ---

# Gerando o gráfico
splot = sns.barplot(x='state', y='deaths_per_100k_inhabitants', data=obitos_normalizados, ax=ax, color='DarkOrange')


for p in splot.patches:
    height = p.get_height()

    # Gerando texto para as barras
    splot.annotate('{}'.format(round(p.get_height(), 2)),
                (p.get_x() + p.get_width()/2, p.get_height()),
                ha='center',
                va='center',
                size=12, 
                color='white', 
                fontweight='bold',
                xytext=(0,-15),
                textcoords='offset points')

# Configurações de Layout do gráfico

ax.set_title('Óbitos normalizados por 100 mil habitantes\n\n', loc='left', size=22, color='grey')

ax.set_xlabel([], color='white')
ax.set_ylabel([], color='white')
ax.set_yticklabels([])
ax.set_xticklabels(obitos_normalizados['state'].to_list(), size=12, color='gray')
sns.despine(left=True, bottom=True)

plt.tight_layout()

# %% [markdown]
# Usando os dados de óbitos normalizados por 100 mil habitantes, vemos que o Rondônia é o estado que mais possui óbitos por 100 mil habitantes, o Rio de Janeiro aparece na 4ª posição, indicando realmente uma alta letalidade no estado, que deve ser analisada mais a fundo para entender o motivo pelo qual o estado apresenta uma letalidade relativamente alta.
#
# A vacinação no Brasil começou no dia 17 de Janeiro de 2021, veremos agora como está a situação da vacinação nos estados atualmente.

# %%
df_estados.sample(10)
# Out:
#        epi_week  ... vaccinated_second_per_100k_inhabitants
# 4292         33  ...                                    NaN
# 1710         20  ...                                    NaN
# 1075         17  ...                                    NaN
# 10509       112  ...                             1638.76447
# 8773        103  ...                                    NaN
# 3393         28  ...                                    NaN
# 5736         40  ...                                    NaN
# 12690       123  ...                             7712.36056
# 4261         33  ...                                    NaN
# 5377         39  ...                                    NaN
#
# [10 rows x 22 columns]

# %% [markdown]
# Para usar como parâmetro de avanço da vacinação, usaremos como métrica os dados sobre a segunda dose da vacina, pois ela nos indica quantos realmente estão devidamente imunizados.

# %%
vacinacao_total = (df_estados.loc[(df_estados.date == "2021-06-14") & 
                                  (df_estados.vaccinated.notnull()),
                                  ['state', 'vaccinated', 'vaccinated_second']].sort_values(
                                      by='vaccinated_second',
                                       ascending=False))

vacinacao_total
# Out:
#       state  vaccinated  vaccinated_second
# 12863    SP  13641257.0          5965429.0
# 12848    MG   5428474.0          2542292.0
# 12856    RJ   4606151.0          1874877.0
# 12860    RS   3803251.0          1630278.0
# 12842    BA   4109720.0          1610546.0
# 12855    PR   3239009.0          1280839.0
# 12843    CE   2134125.0          1092163.0
# 12853    PE   2450776.0          1001355.0
# 12851    PA   1615124.0           795056.0
# 12861    SC   2131657.0           765289.0
# 12846    GO   1788363.0           675069.0
# 12847    MA   1703083.0           564448.0
# 12840    AM   1101421.0           508414.0
# 12852    PB    988662.0           465653.0
# 12845    ES   1238792.0           461170.0
# 12849    MS   1015255.0           389367.0
# 12857    RN    874849.0           388411.0
# 12844    DF    782763.0           327448.0
# 12854    PI    768046.0           306464.0
# 12839    AL    827565.0           299859.0
# 12850    MT    739634.0           298003.0
# 12862    SE    591572.0           210993.0
# 12858    RO    342205.0           140924.0
# 12864    TO    320533.0           137443.0
# 12838    AC    156828.0            63688.0
# 12859    RR    110817.0            63035.0
# 12841    AP    147449.0            61444.0

# %%
# Gráfico de vacinação total

# Configuração do Gráfico
sns.set_style('white')
fig, ax = plt.subplots(figsize=(12,8))

sns.barplot(x='vaccinated', y='state', data=vacinacao_total[:10], ax=ax, orient='h', color='Grey')

# Gerando o gráfico
splot = sns.barplot(x='vaccinated_second', y='state',
                    data=vacinacao_total[:10], ax=ax, orient='h', color='DarkOrange')

for p in splot.patches:
    width = round(p.get_width()/1000000, 2)

        
    if width >= 1.6 and width <= 3.6:
        plt.text(p.get_width()/1.3, p.get_y()+0.55*p.get_height(),
                '{}M'.format(width),
                ha='center', va='center', color='white', size=10, fontweight='bold')
    
    elif width >= 0.1 and width <= 1.5:
        plt.text(p.get_width()/1.60, p.get_y()+0.55*p.get_height(),
                '{}M'.format(width),
                ha='center', va='center', color='white', size=10, fontweight='bold')

          
    else:
        plt.text(p.get_width()/1.1, p.get_y()+0.55*p.get_height(),
                '{}M'.format(width),
                ha='center', va='center', color='white', size=10, fontweight='bold')

    
    

ax.set_title('Total de vacinas administradas\n\n\n', loc='left', size=20, color='grey')
plt.suptitle('Valores arredondados em milhões- em 14 de Junho de 2021', x=0.265, y=0.940, color='gray', size=12)
plt.text(x=100, y=-0.75, s="\n■ Segunda Dose", size=12, color='DarkOrange', fontweight='light',)
plt.text(x=2250000, y=-0.75, s="\n■ Primeira Dose", size=12, color='Grey', fontweight='light',)

ax.set_xlabel([], color='white')
ax.set_ylabel([], color='white')
ax.set_xticklabels([])

sns.despine(left=True, bottom=True)

plt.tight_layout()

# %% [markdown]
# Levando em consideração a segunda dose da vacina que é quando as pessoas estão devidamente imunizadas, São Paulo segue como o estado que mais vacinou em números absolutos com quase 6 milhões da segunda dose administrada, seguido de Minas Gerais, Rio de Janeiro, Rio Grande do Sul e Bahia. Como vimos anteriormente, para efeito de comparação, devemos usar os dados normalizados para não sofrermos com o efeito da população.

# %%
vacinacao_normalizado = (df_estados.loc[(df_estados["date"] == "2021-06-14") & 
                                        (df_estados["vaccinated"].notnull())]
                         [["state", "vaccinated_per_100k_inhabitants", "vaccinated_second_per_100k_inhabitants"]]
                         .sort_values(by="vaccinated_second_per_100k_inhabitants", ascending=False))

vacinacao_normalizado
# Out:
#       state  ...  vaccinated_second_per_100k_inhabitants
# 12860    RS  ...                             14329.29378
# 12849    MS  ...                             14011.11772
# 12863    SP  ...                             12991.18586
# 12840    AM  ...                             12266.91039
# 12848    MG  ...                             12009.62303
# 12843    CE  ...                             11959.63285
# 12852    PB  ...                             11588.80742
# 12845    ES  ...                             11475.74434
# 12855    PR  ...                             11202.06242
# 12857    RN  ...                             11075.77078
# 12844    DF  ...                             10859.66488
# 12856    RJ  ...                             10859.44506
# 12842    BA  ...                             10828.60936
# 12861    SC  ...                             10681.25114
# 12853    PE  ...                             10477.63483
# 12859    RR  ...                             10405.91917
# 12846    GO  ...                              9618.62283
# 12854    PI  ...                              9362.74814
# 12851    PA  ...                              9241.75841
# 12862    SE  ...                              9178.81268
# 12839    AL  ...                              8984.92430
# 12864    TO  ...                              8738.37949
# 12850    MT  ...                              8552.32911
# 12847    MA  ...                              7977.85951
# 12858    RO  ...                              7929.44056
# 12841    AP  ...                              7265.19425
# 12838    AC  ...                              7221.39387
#
# [27 rows x 3 columns]

# %%
# Gráfico do top 10 vacinação normalizados por população

# Configuração do Gráfico
sns.set_style('white')
fig, ax = plt.subplots(figsize=(12,8))

sns.barplot(x='vaccinated_per_100k_inhabitants', y='state', data=vacinacao_normalizado[:10], ax=ax, orient='h', color='Grey')

# Gerando o gráfico
splot = sns.barplot(x='vaccinated_second_per_100k_inhabitants', y='state',
                    data=vacinacao_normalizado[:10], ax=ax, orient='h', color='DarkOrange')

for p in splot.patches:
    width = round(p.get_width()/1000, 2)

    if width <= 20:
        plt.text(p.get_width()/1.2, p.get_y()+0.55*p.get_height(),
                '{} mil'.format(width),
                ha='center', va='center', color='white', size=10, fontweight='bold')

    else:
        plt.text(p.get_width()/1.075, p.get_y()+0.55*p.get_height(),
                '{} mil'.format(width),
                ha='center', va='center', color='white', size=10, fontweight='bold')

    
    

ax.set_title('Vacinas administradas normalizadas\n\n\n', loc='left', size=20, color='grey')
plt.suptitle('Normalizadas por 100 mil habitantes - em 14 de Junho de 2021', x=0.280, y=0.940, color='gray', size=12)

plt.text(x=100, y=-0.75, s="\n■ Segunda Dose", size=12, color='DarkOrange', fontweight='light')
plt.text(x=6000, y=-0.75, s="\n■ Primeira Dose", size=12, color='Grey', fontweight='light')

ax.set_xlabel([], color='white')
ax.set_ylabel([], color='white')
ax.set_xticklabels([])

sns.despine(left=True, bottom=True)

plt.tight_layout()

# %% [markdown]
# Observando os dados normalizados por 100 mil habitantes vimos que o ranking de estados que mais vacinou sua população mudou, mostrando o Rio Grande do Sul como líder de vacinação com 14.33 mil aplicações da segunda dose, seguidos de Mato Grosso do Sul, São Paulo, Amazonas e Minas Gerais.

# %%
# Gráfico de média móvel de novas vacinações normalizadas por milhão de habitantes

sns.set_style('ticks')
fig, ax = plt.subplots(figsize=(12,8))

novas_vacinacoes_brasil = (df_brasil.loc[:, ['date', 'new_vaccinations_smoothed_per_million']].reset_index(drop=True))

novas_vacinacoes_mundial = (df.loc[df.location == 'World', ['date', 'new_vaccinations_smoothed_per_million']].reset_index(drop=True))

sns.lineplot(x='date', y='new_vaccinations_smoothed_per_million',
             data=novas_vacinacoes_brasil, ci=None, linewidth=2, color='DarkOrange')

sns.lineplot(x='date', y='new_vaccinations_smoothed_per_million',
             data=novas_vacinacoes_mundial, ci=None, linewidth=1.2, color='Gray')


ax.set_title('Média móvel (7 dias) de novas vacinações no Brasil\n\n', color='Grey', size=20, loc='left')
plt.suptitle('normalizados por milhão de habitantes', x=0.225, y=0.945, color='Grey', size=14)

ax.text(x=737957, y=4400, s='Brasil', color='DarkOrange', fontweight='bold', size=14)
ax.text(x=737957, y=4100, s='Mundo', color='Gray', size=12)

ax.set_xlabel([], color='white')
ax.set_ylabel([], color='white')


sns.despine()
plt.tight_layout()

# %% [markdown]
# A média de vacinação no Brasil segue em crescimento ao longo do tempo, com algumas quedas nos números que provavelmente sejam devido ao baixo número de vacinas disponíveis durante o período registrado, mas apesar disso, continua em constante evolução em relação a taxa de vacinação mundial.

# %% [markdown]
# ## Conclusão
#
#
# Após analisar os dados obtidos sobre a situação mundial e brasileiras, podemos concluir que:
#
# * A alta taxa de contágio em alguns países podem ser devido ao surgimento de novas variantes do coronovíruas ou por medidas de flexibilização mais brandas.
# * A taxa de reprodução do vírus (R0) nos mostra, em resumo, a velocidade em que a doença se espalha nos países, como por exemplo o R0 do Brasil é de 1.05, ou seja, ainda está se espalhando pelo país.
# * A média móvel de novos casos no Brasil é maior que a taxa mundial de novos casos.
# * Apesar de possuir uma quantidade relativamente baixa de casos registrados, o Rio de Janeiro apresenta uma taxa de óbitos relativamente alta comparado com outros estados que possuem aproximadamente o mesmo número de casos do Rio de Janeiro.
# * A vacinação tanto mundial quanto brasileira, seguem em seus estágios iniciais mas que podem refletir na diminuição de casos e mortes futuras.
# * Mesmo que a vacinação em média no Brasil seja maior que a média mundial, os números de óbitos no país são expressivos.
#
# Temos um longo caminho pela frente ainda, mesmo que a vacinação tenha começado recentemente e esteja acelerando gradualmente a cada dia, as medidas simples e eficientes de contenção da propagação do vírus devem continuar sendo respeitadas até que a população esteja devidamente imunizada.
#
# ---
#
# Qualquer dúvida ou sugestão, entre em contato:
#
# * [LinkedIn](https://www.linkedin.com/in/roberto-paixao95/)
# * [E-mail](robertocsp95@gmail.com)
